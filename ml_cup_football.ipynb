# %% [markdown]
# # Import Depedencies

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Loading

# %% [markdown]
# ## Load Dataset

# %%
train_data = pd.read_csv('data/train.csv', index_col=0)
test_data = pd.read_csv('data/test.csv', index_col=0)

# %% [markdown]
# ## Run Data

# %%
train_data.head()
test_data.head()

print(train_data.shape)
print(test_data.shape)
# Out:
#                  match_id        date gender      team  opponent  is_home  \
# Id
# M000001_Scotland  M000001  1872-11-30      M  Scotland   England        1
# M000001_England   M000001  1872-11-30      M   England  Scotland        0
# M000002_England   M000002  1873-03-08      M   England  Scotland        1
# M000002_Scotland  M000002  1873-03-08      M  Scotland   England        0
# M000003_Scotland  M000003  1874-03-07      M  Scotland   England        1
#
#                   neutral tournament venue_country  team_goals  ...  \
# Id                                                              ...
# M000001_Scotland        0   Friendly      Scotland           0  ...
# M000001_England         0   Friendly      Scotland           0  ...
# M000002_England         0   Friendly       England           4  ...
# M000002_Scotland        0   Friendly       England           2  ...
# M000003_Scotland        0   Friendly      Scotland           2  ...
#
#                   confederation_team  confederation_opp  population_team  \
# Id
# M000001_Scotland                UEFA               UEFA              NaN
# M000001_England                 UEFA               UEFA              NaN
# M000002_England                 UEFA               UEFA              NaN
# M000002_Scotland                UEFA               UEFA              NaN
# M000003_Scotland                UEFA               UEFA              NaN
#
#                   population_opp  gdp_per_capita_team  gdp_per_capita_opp  \
# Id
# M000001_Scotland             NaN                  NaN                 NaN
# M000001_England              NaN                  NaN                 NaN
# M000002_England              NaN                  NaN                 NaN
# M000002_Scotland             NaN                  NaN                 NaN
# M000003_Scotland             NaN                  NaN                 NaN
#
#                   altitude_venue  distance_travel_team  distance_travel_opp  \
# Id
# M000001_Scotland             NaN                   NaN                  NaN
# M000001_England              NaN                   NaN                  NaN
# M000002_England              NaN                   NaN                  NaN
# M000002_Scotland             NaN                   NaN                  NaN
# M000003_Scotland             NaN                   NaN                  NaN
#
#                   temperature_venue
# Id
# M000001_Scotland                NaN
# M000001_England                 NaN
# M000002_England                 NaN
# M000002_Scotland                NaN
# M000003_Scotland                NaN
#
# [5 rows x 46 columns]
#
#                    match_id        date gender        team    opponent  \
# Id
# M034984_Seychelles  M034984  2011-08-06      M  Seychelles   Mauritius
# M034984_Mauritius   M034984  2011-08-06      M   Mauritius  Seychelles
# M034985_Comoros     M034985  2011-08-06      M     Comoros    Maldives
# M034985_Maldives    M034985  2011-08-06      M    Maldives     Comoros
# M034986_Réunion     M034986  2011-08-06      M     Réunion  Madagascar
#
#                     is_home  neutral                 tournament venue_country  \
# Id
# M034984_Seychelles        1        0  Indian Ocean Island Games    Seychelles
# M034984_Mauritius         0        0  Indian Ocean Island Games    Seychelles
# M034985_Comoros           1        1  Indian Ocean Island Games    Seychelles
# M034985_Maldives          0        1  Indian Ocean Island Games    Seychelles
# M034986_Réunion           1        1  Indian Ocean Island Games    Seychelles
#
#                    confederation_team confederation_opp  population_team  \
# Id
# M034984_Seychelles                CAF               CAF          92409.0
# M034984_Mauritius                 CAF               CAF        1283330.0
# M034985_Comoros                   CAF               AFC         656024.0
# M034985_Maldives                  AFC               CAF         361575.0
# M034986_Réunion               Unknown               CAF              NaN
#
#                     population_opp  gdp_per_capita_team  gdp_per_capita_opp  \
# Id
# M034984_Seychelles       1283330.0         12189.095160         9197.026972
# M034984_Mauritius          92409.0          9197.026972        12189.095160
# M034985_Comoros           361575.0          1447.945144         7291.465967
# M034985_Maldives          656024.0          7291.465967         1447.945144
# M034986_Réunion         21731053.0                  NaN          531.265432
#
#                     altitude_venue  distance_travel_team  distance_travel_opp  \
# Id
# M034984_Seychelles         -9999.0              0.000000          1751.895724
# M034984_Mauritius          -9999.0           1751.895724             0.000000
# M034985_Comoros            -9999.0           1517.010705          5483.117523
# M034985_Maldives           -9999.0           5483.117523          1517.010705
# M034986_Réunion            -9999.0                   NaN                  NaN
#
#                     temperature_venue
# Id
# M034984_Seychelles          25.790169
# M034984_Mauritius           25.790169
# M034985_Comoros             25.790169
# M034985_Maldives            25.790169
# M034986_Réunion             25.790169
#
# (78772, 46)
# (42422, 19)
