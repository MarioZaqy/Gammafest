# %% [markdown]
# # Import Depedencies

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Loading

# %%
train_data = pd.read_csv('data/train.csv', index_col=0)
test_data = pd.read_csv('data/test.csv', index_col=0)

# %% [markdown]
# # Data Understanding

# %%
train_data.head()
print(train_data.shape, '\n')
print(train_data.info(), '\n')

test_data.head()
print(test_data.shape, '\n')
print(test_data.info(), '\n')
# Out:
# (78772, 46)
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 78772 entries, M000001_Scotland to M034983_Mauritius
# Data columns (total 46 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   match_id                    78772 non-null  object
#  1   date                        78772 non-null  object
#  2   gender                      78772 non-null  object
#  3   team                        78772 non-null  object
#  4   opponent                    78772 non-null  object
#  5   is_home                     78772 non-null  int64
#  6   neutral                     78772 non-null  int64
#  7   tournament                  78772 non-null  object
#  8   venue_country               78772 non-null  object
#  9   team_goals                  78772 non-null  int64
#  10  opp_goals                   78772 non-null  int64
#  11  team_points_last5           78478 non-null  float64
#  12  opp_points_last5            78596 non-null  float64
#  13  points_last5_diff           78332 non-null  float64
#  14  team_gd_last5               78478 non-null  float64
#  15  opp_gd_last5                78596 non-null  float64
#  16  gd_last5_diff               78332 non-null  float64
#  17  h2h_points_last5            66796 non-null  float64
#  18  h2h_gd_last5                66796 non-null  float64
#  19  days_since_last_match_team  78478 non-null  float64
#  20  days_since_last_match_opp   78596 non-null  float64
#  21  team_points_last10          78478 non-null  float64
#  22  opp_points_last10           78596 non-null  float64
#  23  team_avg_goals_last5        78478 non-null  float64
#  24  team_avg_conceded_last5     78478 non-null  float64
#  25  opp_avg_goals_last5         78596 non-null  float64
#  26  opp_avg_conceded_last5      78596 non-null  float64
#  27  team_win_rate_last10        78478 non-null  float64
#  28  opp_win_rate_last10         78596 non-null  float64
#  29  elo_team                    78772 non-null  float64
#  30  elo_opponent                78772 non-null  float64
#  31  rank_team                   36826 non-null  float64
#  32  rank_opponent               36826 non-null  float64
#  33  rank_diff                   34870 non-null  float64
#  34  rank_missing_team           78772 non-null  int64
#  35  rank_missing_opp            78772 non-null  int64
#  36  confederation_team          78772 non-null  object
#  37  confederation_opp           78772 non-null  object
#  38  population_team             63900 non-null  float64
#  39  population_opp              63900 non-null  float64
#  40  gdp_per_capita_team         52815 non-null  float64
#  41  gdp_per_capita_opp          52815 non-null  float64
#  42  altitude_venue              58218 non-null  float64
#  43  distance_travel_team        48380 non-null  float64
#  44  distance_travel_opp         48380 non-null  float64
#  45  temperature_venue           61698 non-null  float64
# dtypes: float64(31), int64(6), object(9)
# memory usage: 28.2+ MB
# None
#
# (42422, 19)
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 42422 entries, M034984_Seychelles to M049215_Comoros
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   match_id              42422 non-null  object
#  1   date                  42422 non-null  object
#  2   gender                42422 non-null  object
#  3   team                  42422 non-null  object
#  4   opponent              42422 non-null  object
#  5   is_home               42422 non-null  int64
#  6   neutral               42422 non-null  int64
#  7   tournament            42422 non-null  object
#  8   venue_country         42422 non-null  object
#  9   confederation_team    42422 non-null  object
#  10  confederation_opp     42422 non-null  object
#  11  population_team       39050 non-null  float64
#  12  population_opp        39050 non-null  float64
#  13  gdp_per_capita_team   27758 non-null  float64
#  14  gdp_per_capita_opp    27758 non-null  float64
#  15  altitude_venue        31516 non-null  float64
#  16  distance_travel_team  25447 non-null  float64
#  17  distance_travel_opp   25447 non-null  float64
#  18  temperature_venue     36828 non-null  float64
# dtypes: float64(8), int64(2), object(9)
# memory usage: 6.5+ MB
# None
